# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import sqlite3

# %% [markdown]
# # Read in MIPS data

# %%
mips = pd.read_csv('data/ec_score_file.csv')

# %%
mips.columns = [col.replace(" ", "").lower() for col in mips.columns]

# %%
mips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 933504 entries, 0 to 933503
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   npi                           933504 non-null  int64
#  1   org_pac_id                    930316 non-null  float64
#  2   lst_nm                        933469 non-null  object
#  3   frst_nm                       933488 non-null  object
#  4   source                        933504 non-null  object
#  5   facility_ccn                  23904 non-null   float64
#  6   facility_lbn                  23901 non-null   object
#  7   quality_category_score        853226 non-null  float64
#  8   pi_category_score             595380 non-null  float64
#  9   ia_category_score             865483 non-null  float64
#  10  cost_category_score           0 non-null       float64
#  11  final_mips_score_without_cpb  933504 non-null  float64
#  12  final_mips_score              933504 non-null  float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 92.6+ MB

# %%
mips.head()
# Out:
#           npi  org_pac_id                lst_nm  frst_nm      source  \
# 0  1003028101         NaN                  KATZ  KENNETH  individual
# 1  1003028556         NaN               HEIDARI     NEDA  individual
# 2  1003156209         NaN  GUERRA  DEL CASTILLO  ROBERTO         apm
# 3  1003162173         NaN          HASSAN KAMEL  MOHAMED         apm
# 4  1003220351         NaN               NAUMOVA    YULIA  individual
#
#    facility_ccn facility_lbn  quality_category_score  pi_category_score  \
# 0           NaN          NaN                     NaN                NaN
# 1           NaN          NaN                     NaN                NaN
# 2           NaN          NaN                     NaN                NaN
# 3           NaN          NaN                     NaN                NaN
# 4           NaN          NaN                     NaN                NaN
#
#    ia_category_score  cost_category_score  final_mips_score_without_cpb  \
# 0                NaN                  NaN                          45.0
# 1                NaN                  NaN                          45.0
# 2                NaN                  NaN                          45.0
# 3                NaN                  NaN                          45.0
# 4                NaN                  NaN                          45.0
#
#    final_mips_score
# 0              45.0
# 1              45.0
# 2              45.0
# 3              45.0
# 4              45.0

# %%
mips_cols = ['npi', 
             'quality_category_score', 
             'pi_category_score', 
             'ia_category_score', 
             'final_mips_score_without_cpb', 
             'final_mips_score']

# %%
mips_thin = mips[mips_cols]

# %%
mips_thin
# Out:
#                npi  quality_category_score  pi_category_score  \
# 0       1003028101                     NaN                NaN
# 1       1003028556                     NaN                NaN
# 2       1003156209                     NaN                NaN
# 3       1003162173                     NaN                NaN
# 4       1003220351                     NaN                NaN
# ...            ...                     ...                ...
# 933499  1265429369                    90.4               92.0
# 933500  1649554882                    94.4               89.0
# 933501  1811984917                    89.8               95.0
# 933502  1891957023                    85.3               90.0
# 933503  1982609657                   100.0               93.0
#
#         ia_category_score  final_mips_score_without_cpb  final_mips_score
# 0                     NaN                          45.0              45.0
# 1                     NaN                          45.0              45.0
# 2                     NaN                          45.0              45.0
# 3                     NaN                          45.0              45.0
# 4                     NaN                          45.0              45.0
# ...                   ...                           ...               ...
# 933499               40.0                          92.3              98.1
# 933500               40.0                          93.6              98.1
# 933501               40.0                          92.9              96.2
# 933502               40.0                          88.9              93.6
# 933503               40.0                          97.9             100.0
#
# [933504 rows x 6 columns]

# %% [markdown]
# # Read in Sample Sets

# %%
tncosts_full = pd.read_csv('data/Medicare_Physician_Other_Practitioners_by_Provider_and_Service_2019_TN.csv')
tncosts_full.columns
# Out:
# Index(['Rndrng_NPI', 'Rndrng_Prvdr_Last_Org_Name', 'Rndrng_Prvdr_First_Name',
#        'Rndrng_Prvdr_MI', 'Rndrng_Prvdr_Crdntls', 'Rndrng_Prvdr_Gndr',
#        'Rndrng_Prvdr_Ent_Cd', 'Rndrng_Prvdr_St1', 'Rndrng_Prvdr_St2',
#        'Rndrng_Prvdr_City', 'Rndrng_Prvdr_State_Abrvtn',
#        'Rndrng_Prvdr_State_FIPS', 'Rndrng_Prvdr_Zip5', 'Rndrng_Prvdr_RUCA',
#        'Rndrng_Prvdr_RUCA_Desc', 'Rndrng_Prvdr_Cntry', 'Rndrng_Prvdr_Type',
#        'Rndrng_Prvdr_Mdcr_Prtcptg_Ind', 'HCPCS_Cd', 'HCPCS_Desc',
#        'HCPCS_Drug_Ind', 'Place_Of_Srvc', 'Tot_Benes', 'Tot_Srvcs',
#        'Tot_Bene_Day_Srvcs', 'Avg_Sbmtd_Chrg', 'Avg_Mdcr_Alowd_Amt',
#        'Avg_Mdcr_Pymt_Amt', 'Avg_Mdcr_Stdzd_Amt'],
#       dtype='object')

# %%
tncosts_cols = ['Rndrng_NPI', 
                'Rndrng_Prvdr_Last_Org_Name', 
                'Rndrng_Prvdr_First_Name',
                'Rndrng_Prvdr_Crdntls',
                'Rndrng_Prvdr_Type', 
                'HCPCS_Cd', 
                'HCPCS_Desc',
                'Place_Of_Srvc',
                'Tot_Benes', 
                'Tot_Srvcs',
                'Tot_Bene_Day_Srvcs',
                'Avg_Sbmtd_Chrg', 
                'Avg_Mdcr_Alowd_Amt', 
                'Avg_Mdcr_Pymt_Amt', 
                'Avg_Mdcr_Stdzd_Amt']

tncosts = tncosts_full[tncosts_cols]

# %%
tncosts.columns = [col.replace('Rndrng_', '').replace("Prvdr_", "").lower() for col in tncosts.columns]

# %%
rename_dict = {
    'type': 'specialty',
    'last_org_name':'last_name', 
    'first_name': 'first_name',
    'crdntls': 'credentials',
    'hcpcs_cd': 'procedure_code', 
    'hcpcs_desc': 'procedure_description',
    'place_of_srvc': 'place_of_service',
    'tot_benes': 'total_beneficiaries', 
    'tot_srvcs': 'total_services',
    'tot_bene_day_srvcs': 'total_beneficiaries_per_day_services',
    'avg_sbmtd_chrg': 'avg_submitted_charge', 
    'avg_mdcr_alowd_amt': 'avg_medicare_allowed', 
    'avg_mdcr_pymt_amt': 'avg_medicare_payment',
    'avg_mdcr_stdzd_amt': 'avg_medicare_standardized_payment'
}

tn_costs = tncosts.rename(columns = rename_dict)

# %%
tn_costs.columns
# Out:
# Index(['npi', 'last_name', 'first_name', 'credentials', 'specialty',
#        'procedure_code', 'procedure_description', 'place_of_service',
#        'total_beneficiaries', 'total_services',
#        'total_beneficiaries_per_day_services', 'avg_submitted_charge',
#        'avg_medicare_allowed', 'avg_medicare_payment',
#        'avg_medicare_standardized_payment'],
#       dtype='object')

# %% [markdown]
# # Modify the tom_cruise DB

# %%
with sqlite3.connect('data/tom_cruise.sqlite') as db: 
    cursor = db.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    print(cursor.fetchall())
    cursor.close()
# Out:
# [('profile',), ('taxonomy',), ('zip_cbsa',), ('affiliations',)]

# %%
# tables = ['referral_from', 'referral_to', 'referrals']

# with sqlite3.connect('data/tom_cruise.sqlite') as db:
    
#     for table in tables:
    
#         query = f"""

#         DROP TABLE {table};

#         """
        
#         db.execute(query)

# %% [markdown]
# # Read in geocodes

# %%
geo = pd.read_csv('data/to_address_geocodes_big.csv').rename(columns = {"address_to":"address"})
geo
# Out:
#                                                 address        lat        lng
# 0             400 E PUBLIC SQUARE, ALEXANDRIA, TN 37012  36.077559 -86.033322
# 1                5801 CROSSINGS BLVD, ANTIOCH, TN 37013  36.037696 -86.642255
# 2                 5323 MOUNT VIEW RD, ANTIOCH, TN 37013  36.048716 -86.647766
# 3             889B BELL RD, STE A-7A, ANTIOCH, TN 37013  36.050291 -86.650860
# 4                        777 BELL RD, ANTIOCH, TN 37013  36.051049 -86.649262
# ...                                                 ...        ...        ...
# 3813  112 BRADFORD BLVD STE 500, GORDONSVILLE, TN 38563  36.178176 -85.949145
# 3814                 126 JMZ DR, GORDONSVILLE, TN 38563  36.190714 -85.951012
# 3815  112 BRADFORD BLVD, SUITE 500, GORDONSVILLE, TN...  36.178176 -85.949145
# 3816  8 NEW MIDDLETON HWY, STE A, GORDONSVILLE, TN 3...  36.173668 -85.947819
# 3817    14 MAIN STREET, SUITE B, GORDONSVILLE, TN 38563  36.172716 -85.944706
#
# [3818 rows x 3 columns]

# %% [markdown]
# # Pull profiles and taxonomies from tom_cruise db

# %%
# %%time
# referrals from providers (entity 1) to metro nashville groups (entity 2) 
# having over 50 transactions and under 50 average wait time
query = """

    SELECT
            npi,
            entity_type_code,
            "provider_last_name_(legal_name)" || ', ' || provider_first_name AS name,
            taxonomy_code,
            classification,
            specialization,
            "provider_organization_name_(legal_business_name)" AS organization,
            provider_first_line_business_practice_location_address AS address_line1,
            provider_second_line_business_practice_location_address AS address_line2,
            provider_business_practice_location_address_city_name AS city,
            provider_business_practice_location_address_state_name AS state,
            provider_business_practice_location_address_postal_code AS zip
    FROM profile
    INNER JOIN taxonomy
    ON profile.taxonomy_code = taxonomy.code
    WHERE provider_business_practice_location_address_postal_code IN (
        SELECT zip
        FROM zip_cbsa
        WHERE cbsa = '34980'
        )

"""
with sqlite3.connect('data/tom_cruise.sqlite') as db:
    profiles = pd.read_sql(query, db)

profiles
# Out:
# Wall time: 1.25 s
#               npi  entity_type_code               name taxonomy_code  \
# 0      1346216199               1.0  GERTONSON, STEVEN    367500000X
# 1      1649660085               1.0     SMITH, KALEENA    235Z00000X
# 2      1811367980               1.0     GRAMLICK, RENE    133V00000X
# 3      1760929236               1.0       HUFF, SYDNEY    390200000X
# 4      1740720275               2.0               None    261QM1300X
# ...           ...               ...                ...           ...
# 44218  1194394767               1.0      VADEN, CHARLI    225100000X
# 44219  1518611425               1.0        SIRCY, ANNA    363LF0000X
# 44220  1831561059               1.0  MONTALBO, CYNTHIA    224Z00000X
# 44221  1558875468               2.0               None    343900000X
# 44222  1730364720               1.0  SEMBRANO, CARMELO    225100000X
#
#                                           classification   specialization  \
# 0                Nurse Anesthetist, Certified Registered             None
# 1                            Speech-Language Pathologist             None
# 2                                  Dietitian, Registered             None
# 3      Student in an Organized Health Care Education/...             None
# 4                                          Clinic/Center  Multi-Specialty
# ...                                                  ...              ...
# 44218                                 Physical Therapist             None
# 44219                                 Nurse Practitioner           Family
# 44220                     Occupational Therapy Assistant             None
# 44221              Non-emergency Medical Transport (VAN)             None
# 44222                                 Physical Therapist             None
#
#                          organization                   address_line1  \
# 0                                None                1950 BRADBURY RD
# 1                                None                   948 NECTAR CT
# 2                                None  2875 OLD CLARKSVILLE SPGFLD RD
# 3                                None                    3835 HEAD RD
# 4            CHS TENNESSEE MEDICAL PC                4538 GUTHRIE HWY
# ...                               ...                             ...
# 44218                            None    417 GORDONSVILLE HWY STE 100
# 44219                            None             8 NEW MIDDLETON HWY
# 44220                            None                   73 JUDKINS LN
# 44221  BLUE HERON TRANSPORTATION, LLC                 177 SPURLOCK LN
# 44222                            None            480 SMOKEY BRANCH LN
#
#       address_line2          city state    zip
# 0              None         ADAMS    TN  37010
# 1              None         ADAMS    TN  37010
# 2              None         ADAMS    TN  37010
# 3              None         ADAMS    TN  37010
# 4              None   CLARKSVILLE    TN  37010
# ...             ...           ...   ...    ...
# 44218          None  GORDONSVILLE    TN  38563
# 44219          None  GORDONSVILLE    TN  38563
# 44220          None       HICKMAN    TN  38567
# 44221          None       HICKMAN    TN  38567
# 44222          None  WHITLEYVILLE    TN  38588
#
# [44223 rows x 12 columns]

# %% [markdown]
# # Build full addresses

# %%
def build_address(df):
    address = ((df['address_line1'] + ', ' + df['address_line2']).mask(pd.isna, df['address_line1'])
         + ', ' 
         + df['city'] 
         + ', ' 
         + df['state']
         + ' '
         + df['zip']
    )
    return address

# %%
profiles['address'] = build_address(profiles)
# Out:
#               npi  entity_type_code               name taxonomy_code  \
# 0      1346216199               1.0  GERTONSON, STEVEN    367500000X
# 1      1649660085               1.0     SMITH, KALEENA    235Z00000X
# 2      1811367980               1.0     GRAMLICK, RENE    133V00000X
# 3      1760929236               1.0       HUFF, SYDNEY    390200000X
# 4      1740720275               2.0               None    261QM1300X
# ...           ...               ...                ...           ...
# 44218  1194394767               1.0      VADEN, CHARLI    225100000X
# 44219  1518611425               1.0        SIRCY, ANNA    363LF0000X
# 44220  1831561059               1.0  MONTALBO, CYNTHIA    224Z00000X
# 44221  1558875468               2.0               None    343900000X
# 44222  1730364720               1.0  SEMBRANO, CARMELO    225100000X
#
#                                           classification   specialization  \
# 0                Nurse Anesthetist, Certified Registered             None
# 1                            Speech-Language Pathologist             None
# 2                                  Dietitian, Registered             None
# 3      Student in an Organized Health Care Education/...             None
# 4                                          Clinic/Center  Multi-Specialty
# ...                                                  ...              ...
# 44218                                 Physical Therapist             None
# 44219                                 Nurse Practitioner           Family
# 44220                     Occupational Therapy Assistant             None
# 44221              Non-emergency Medical Transport (VAN)             None
# 44222                                 Physical Therapist             None
#
#                          organization                   address_line1  \
# 0                                None                1950 BRADBURY RD
# 1                                None                   948 NECTAR CT
# 2                                None  2875 OLD CLARKSVILLE SPGFLD RD
# 3                                None                    3835 HEAD RD
# 4            CHS TENNESSEE MEDICAL PC                4538 GUTHRIE HWY
# ...                               ...                             ...
# 44218                            None    417 GORDONSVILLE HWY STE 100
# 44219                            None             8 NEW MIDDLETON HWY
# 44220                            None                   73 JUDKINS LN
# 44221  BLUE HERON TRANSPORTATION, LLC                 177 SPURLOCK LN
# 44222                            None            480 SMOKEY BRANCH LN
#
#       address_line2          city state    zip  \
# 0              None         ADAMS    TN  37010
# 1              None         ADAMS    TN  37010
# 2              None         ADAMS    TN  37010
# 3              None         ADAMS    TN  37010
# 4              None   CLARKSVILLE    TN  37010
# ...             ...           ...   ...    ...
# 44218          None  GORDONSVILLE    TN  38563
# 44219          None  GORDONSVILLE    TN  38563
# 44220          None       HICKMAN    TN  38567
# 44221          None       HICKMAN    TN  38567
# 44222          None  WHITLEYVILLE    TN  38588
#
#                                                  address
# 0                      1950 BRADBURY RD, ADAMS, TN 37010
# 1                         948 NECTAR CT, ADAMS, TN 37010
# 2        2875 OLD CLARKSVILLE SPGFLD RD, ADAMS, TN 37010
# 3                          3835 HEAD RD, ADAMS, TN 37010
# 4                4538 GUTHRIE HWY, CLARKSVILLE, TN 37010
# ...                                                  ...
# 44218  417 GORDONSVILLE HWY STE 100, GORDONSVILLE, TN...
# 44219        8 NEW MIDDLETON HWY, GORDONSVILLE, TN 38563
# 44220                   73 JUDKINS LN, HICKMAN, TN 38567
# 44221                 177 SPURLOCK LN, HICKMAN, TN 38567
# 44222       480 SMOKEY BRANCH LN, WHITLEYVILLE, TN 38588
#
# [44223 rows x 13 columns]

# %% [markdown]
# # Combine dataframes to make tn_full

# %%
pro_geo = profiles.merge(geo)

# %%
tncosts_geo = pro_geo.merge(tn_costs, on = 'npi')

# %%
tncosts_geo = tncosts_geo[tncosts_geo['entity_type_code'] == 1.0]

# %%
tncosts_geo_drops = ['entity_type_code', 
                     'name',
                     'taxonomy_code', 
                     'classification',
                     'specialization',
                     'organization', 
                     'address_line1', 
                     'address_line2']

tn_med_costs_geo = tncosts_geo.drop(columns = tncosts_geo_drops)
# Out:
#           npi     city state    zip                                 address  \
# 0  1043218654  ANTIOCH    TN  37013  5801 CROSSINGS BLVD, ANTIOCH, TN 37013
# 1  1043218654  ANTIOCH    TN  37013  5801 CROSSINGS BLVD, ANTIOCH, TN 37013
# 2  1043218654  ANTIOCH    TN  37013  5801 CROSSINGS BLVD, ANTIOCH, TN 37013
# 3  1043218654  ANTIOCH    TN  37013  5801 CROSSINGS BLVD, ANTIOCH, TN 37013
# 4  1043218654  ANTIOCH    TN  37013  5801 CROSSINGS BLVD, ANTIOCH, TN 37013
#
#          lat        lng last_name first_name credentials  ... procedure_code  \
# 0  36.037696 -86.642255    Miller    Timothy        M.D.  ...          20552
# 1  36.037696 -86.642255    Miller    Timothy        M.D.  ...          20610
# 2  36.037696 -86.642255    Miller    Timothy        M.D.  ...          27096
# 3  36.037696 -86.642255    Miller    Timothy        M.D.  ...          62321
# 4  36.037696 -86.642255    Miller    Timothy        M.D.  ...          62323
#
#                                procedure_description place_of_service  \
# 0     Injections of trigger points in 1 or 2 muscles                O
# 1  Aspiration and/or injection of large joint or ...                O
# 2  Injection procedure into sacroiliac joint for ...                O
# 3  Injection of substance into spinal canal of up...                F
# 4  Injection of substance into spinal canal of lo...                F
#
#   total_beneficiaries  total_services  total_beneficiaries_per_day_services  \
# 0                  15            18.0                                    18
# 1                  31            39.0                                    39
# 2                  16            16.0                                    16
# 3                  15            18.0                                    18
# 4                  65           103.0                                   103
#
#    avg_submitted_charge  avg_medicare_allowed  avg_medicare_payment  \
# 0            231.176667             52.110000             41.630000
# 1            268.335385             58.047179             43.968974
# 2            583.257500            150.920000            120.570000
# 3            917.498889            103.960556             78.417222
# 4            874.569223             94.629709             73.686990
#
#    avg_medicare_standardized_payment
# 0                          44.360000
# 1                          48.745897
# 2                         128.840000
# 3                          82.256667
# 4                          78.663398
#
# [5 rows x 21 columns]

# %%
tn_full = tn_med_costs_geo.merge(mips_thin, on = 'npi')
tn_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59098 entries, 0 to 59097
# Data columns (total 26 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   npi                                   59098 non-null  int64
#  1   city                                  59098 non-null  object
#  2   state                                 59098 non-null  object
#  3   zip                                   59098 non-null  object
#  4   address                               59098 non-null  object
#  5   lat                                   59098 non-null  float64
#  6   lng                                   59098 non-null  float64
#  7   last_name                             59098 non-null  object
#  8   first_name                            59098 non-null  object
#  9   credentials                           57157 non-null  object
#  10  specialty                             59098 non-null  object
#  11  procedure_code                        59098 non-null  object
#  12  procedure_description                 59098 non-null  object
#  13  place_of_service                      59098 non-null  object
#  14  total_beneficiaries                   59098 non-null  int64
#  15  total_services                        59098 non-null  float64
#  16  total_beneficiaries_per_day_services  59098 non-null  int64
#  17  avg_submitted_charge                  59098 non-null  float64
#  18  avg_medicare_allowed                  59098 non-null  float64
#  19  avg_medicare_payment                  59098 non-null  float64
#  20  avg_medicare_standardized_payment     59098 non-null  float64
#  21  quality_category_score                55026 non-null  float64
#  22  pi_category_score                     29563 non-null  float64
#  23  ia_category_score                     55261 non-null  float64
#  24  final_mips_score_without_cpb          59098 non-null  float64
#  25  final_mips_score                      59098 non-null  float64
# dtypes: float64(12), int64(3), object(11)
# memory usage: 12.2+ MB

# %%
tn_full.to_csv('data/danger_zone.csv', index = False)

# %% [markdown]
# # Explore tn_full

# %%
tn_full.groupby(['procedure_description', 'place_of_service'])['avg_submitted_charge'].agg(['mean', 'std']).reset_index()
# Out:
#                                   procedure_description place_of_service  \
# 0                             3D radiographic procedure                F
# 1                             3D radiographic procedure                O
# 2     3D radiographic procedure with computerized im...                F
# 3     3D radiographic procedure with computerized im...                O
# 4                   5% dextrose/water (500 ml = 1 unit)                O
# ...                                                 ...              ...
# 2022                            X-ray of wrist, 2 views                O
# 2023                 X-ray of wrist, minimum of 3 views                F
# 2024                 X-ray of wrist, minimum of 3 views                O
# 2025      X-ray survey of forearm or wrist bone density                F
# 2026      X-ray survey of forearm or wrist bone density                O
#
#             mean         std
# 0      33.257486    9.365621
# 1     172.344618  137.502783
# 2     110.352222   31.202294
# 3     110.568543   32.406121
# 4      20.000000         NaN
# ...          ...         ...
# 2022   63.585373   17.356806
# 2023   38.135544   13.672381
# 2024   97.518674   22.845509
# 2025  116.923077    7.488453
# 2026   92.000000         NaN
#
# [2027 rows x 4 columns]
